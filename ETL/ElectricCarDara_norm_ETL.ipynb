# %% [markdown]
# Importamos las librerias

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import pyarrow as pa

# %% [markdown]
# Abrimos el archivo

# %%
ruta_archivo = 'D:/escritorio/NYC-TAXIS/NYC_TAXIS-CO2/Data/Original/ElectricCarData_Norm.csv'
Ecdn = pd.read_csv(ruta_archivo)

tipos_de_datos = Ecdn.dtypes

print(tipos_de_datos)
# Out:
# Brand          object
# Model          object
# Accel          object
# TopSpeed       object
# Range          object
# Efficiency     object
# FastCharge     object
# RapidCharge    object
# PowerTrain     object
# PlugType       object
# BodyStyle      object
# Segment        object
# Seats           int64
# PriceEuro       int64
# dtype: object

# %% [markdown]
# Vamos a ver que tipos de datos poseen cada columnas

# %%
valores_nulos = Ecdn.isnull().sum()
print("\nCantidad de valores nulos por columna:")
print(valores_nulos)
# Out:
# Cantidad de valores nulos por columna:
# Brand          0
# Model          0
# Accel          0
# TopSpeed       0
# Range          0
# Efficiency     0
# FastCharge     0
# RapidCharge    0
# PowerTrain     0
# PlugType       0
# BodyStyle      0
# Segment        0
# Seats          0
# PriceEuro      0
# dtype: int64

# %% [markdown]
# Consultamos si tenemos valores duplicados

# %%
# Verifica si hay valores duplicados en todo el DataFrame
duplicados = Ecdn.duplicated()

# Muestra los valores duplicados
print("¿Hay valores duplicados en el DataFrame?:", duplicados.any())
# Out:
# ¿Hay valores duplicados en el DataFrame?: False

# %% [markdown]
# Vemos las tablas

# %%
Ecdn
# Out:
#            Brand                            Model     Accel  TopSpeed   Range  \
# 0         Tesla     Model 3 Long Range Dual Motor   4.6 sec  233 km/h  450 km
# 1    Volkswagen                         ID.3 Pure  10.0 sec  160 km/h  270 km
# 2      Polestar                                 2   4.7 sec  210 km/h  400 km
# 3           BMW                              iX3    6.8 sec  180 km/h  360 km
# 4         Honda                                e    9.5 sec  145 km/h  170 km
# ..           ...                              ...       ...       ...     ...
# 98       Nissan                       Ariya 63kWh   7.5 sec  160 km/h  330 km
# 99         Audi     e-tron S Sportback 55 quattro   4.5 sec  210 km/h  335 km
# 100      Nissan               Ariya e-4ORCE 63kWh   5.9 sec  200 km/h  325 km
# 101      Nissan   Ariya e-4ORCE 87kWh Performance   5.1 sec  200 km/h  375 km
# 102       Byton                 M-Byte 95 kWh 2WD   7.5 sec  190 km/h  400 km
#
# ...

# %% [markdown]
# Por lo que vemos esta todo en orden las tablas, y vamos a proceder a eliminar las columnas que no vamos a requerir para llevar adelante el proyecto

# %%
# Elimina múltiples columnas
Ecdn_limpio = ['PowerTrain', 'Efficiency', 'FastCharge', 'RapidCharge', 'PlugType', 'BodyStyle', 'Segment', 'Seats']
Ecdn_limpio = Ecdn.drop(columns=Ecdn_limpio)

# %% [markdown]
# Observamos la tabla limpia

# %%
Ecdn_limpio
# Out:
#            Brand                            Model     Accel  TopSpeed   Range  \
# 0         Tesla     Model 3 Long Range Dual Motor   4.6 sec  233 km/h  450 km
# 1    Volkswagen                         ID.3 Pure  10.0 sec  160 km/h  270 km
# 2      Polestar                                 2   4.7 sec  210 km/h  400 km
# 3           BMW                              iX3    6.8 sec  180 km/h  360 km
# 4         Honda                                e    9.5 sec  145 km/h  170 km
# ..           ...                              ...       ...       ...     ...
# 98       Nissan                       Ariya 63kWh   7.5 sec  160 km/h  330 km
# 99         Audi     e-tron S Sportback 55 quattro   4.5 sec  210 km/h  335 km
# 100      Nissan               Ariya e-4ORCE 63kWh   5.9 sec  200 km/h  325 km
# 101      Nissan   Ariya e-4ORCE 87kWh Performance   5.1 sec  200 km/h  375 km
# 102       Byton                 M-Byte 95 kWh 2WD   7.5 sec  190 km/h  400 km
#
#      PriceEuro
# 0        55480
# ...

# %% [markdown]
# por ultimo vemos si los tipos de datos nuevamente

# %%
tipos_de_datos = Ecdn_limpio.dtypes
print(tipos_de_datos)
# Out:
# Brand        object
# Model        object
# Accel        object
# TopSpeed     object
# Range        object
# PriceEuro     int64
# dtype: object

# %% [markdown]
# Guardamos en formato parquet para que sea mas liviano el archivo

# %%
Ecdn_limpio.to_parquet('D:/escritorio/NYC-TAXIS/NYC_TAXIS-CO2/Data/Normalized/Ecdn_limpio.parquet', index=False)
